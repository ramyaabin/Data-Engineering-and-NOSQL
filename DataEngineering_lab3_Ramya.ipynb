# %% [markdown]
# # <span style='color:Blue'> Data Engineering </span>
# ## <span style='color:Blue'> Roll No: AA.SC.P2MCA2107434 </span>
# ### <span style='color:Blue'> LAB ASSIGNMENT -3 </span>

# %% [markdown]
# #### <span style='font-family:Georgia'> Mongo DB Assignment 3
# #### <span style='font-family:Georgia'> Connect to DB sample_airbnb

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Assignment Q1: Connect to DB sample_airbnb & collections "Listings & Reviews"

# %%
#import packages
import pymongo
from pymongo import MongoClient
from pymongo.errors import OperationFailure
client = MongoClient()

# %%
client = MongoClient('mongodb+srv://mongodb:!amhere4u@clustertrial.9fqlmoq.mongodb.net/?retryWrites=true&w=majority', connect=False)

# %%
#Connect to the database
db_training = client['sample_airbnb']

# %%
db_training.list_collection_names()
# Out:
# ['listingsAndReviews']

# %%
# Connect to the collection "listingsAndReviews"
listing_reviews = db_training.listingsAndReviews

# %% [markdown]
# ### Querying Documents

# %%
db_training.list_collection_names()
# Out:
# ['listingsAndReviews']

# %%
# Connect to the collection "listingsAndReviews"
listing_reviews = db_training.listingsAndReviews

# %%
# Display the first document
listing_reviews.find_one()
# Out:
# {'_id': '10006546',
#  'listing_url': 'https://www.airbnb.com/rooms/10006546',
#  'name': 'Ribeira Charming Duplex',
#  'summary': 'Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.',
# ...

# %%
# Count the number of documents in the collection
listing_reviews.estimated_document_count()
# Out:
# 5555

# %% [markdown]
# ### Assignment Q2: Query the ListingsAndReviews collection to find properties near UNESCO heritage sites

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 3000)

# %%
pd.DataFrame(listing_reviews.find( { "neighborhood_overview": { "$regex":
"UNESCO.*" } }, {"name": 1, "neighborhood_overview": 1, '_id': 0} ))
# Out:
#                                                  name  \
# 0                 Studio + Terrace @ Historic Centre!
# 1                            Loios Studio Apartment 3
# 2                                SANTA CATARINA HOUSE
# 3   Sendme2Portugal @Apart. Eusébio - Estação S.Bento
# 4                            Porto Trindade Cozy Flat
# 5                              JF Cozy Apartment Blue
# 6                             Luxury Porto River View
# 7              Century XIX Designer Flat with balcony
# 8                      Gallery Seaside House at Porto
# 9                       Historic Cellars Flat & Hi-Fi
# 10                               A Cute Room in Balat
# 11  BO - Rua das Aldas (Standard Studio W/River View)
# 12           Oporto Wine Cellars Luxury Apartment III
# 13                    Vila Terra Luxury Apartment III
#
# ...

# %% [markdown]
# ### Assignment Q3: Create a few documents and insert it into the Listingsandreview collections

# %%
article1 = {"name": "Luxury Spacious Apartment",
           "summary": "An expensive house with modern kitchen and garden",
           "space":"The spacious double room comes fully furnished with a double bed, closet space as well as a desk",
           "description":"Spend few days in our house for a week",
           "property_type":"Apartment","room_type":"Private room","bed_type":"king size Bed",
            "minimum_nights":"5","maximum_nights":"120","cancellation_policy":"strict"}

# %%
article2 = {"name":"2 BHK furnished apartment",
          "summary":"spend time at the weekend where all facilities in a apartment",
          "space":"spacious and luxury",
          "description":"enjoy your days with our Luxurious apartment",
          "property_type":"Luxurious apartment","room_type":"Private room","bed_type":"king bed",
          "minimum_nights":"3","maximum_nights":"120","cancellation_policy":"strict"}

# %%
result = listing_reviews.insert_many([article1,article2])

# %%
print("New article keys are: {}".format(result.inserted_ids))
# Out:
# New article keys are: [ObjectId('63da769266f92b457cc33469'), ObjectId('63da769266f92b457cc3346a')]

# %%
for doc in listing_reviews.find({},{ "_id": 0, "name": 1, "propert_type": 1}):
    print(doc)
# Out:
# {'name': 'Ribeira Charming Duplex'}
# {'name': 'Horto flat with small garden'}
# {'name': 'Ocean View Waikiki Marina w/prkg'}
# {'name': 'Private Room in Bushwick'}
# {'name': 'Apt Linda Vista Lagoa - Rio'}
# {'name': 'New York City - Upper West Side Apt'}
# {'name': 'Copacabana Apartment Posto 6'}
# {'name': 'Charming Flat in Downtown Moda'}
# {'name': "Catete's Colonial Big Hause Room B"}
# {'name': 'Modern Spacious 1 Bedroom Loft'}
# {'name': 'Deluxe Loft Suite'}
# {'name': 'Ligne verte - à 15 min de métro du centre ville.'}
# {'name': 'Soho Cozy, Spacious and Convenient'}
# {'name': '3 chambres au coeur du Plateau'}
# {'name': 'Ótimo Apto proximo Parque Olimpico'}
# {'name': 'Double Room en-suite (307)'}
# {'name': 'Nice room in Barcelona Center'}
# {'name': 'Be Happy in Porto'}
# {'name': 'City center private room with bed'}
# {'name': 'Surry Hills Studio - Your Perfect Base in Sydney'}
# {'name': 'Cozy house at Beyoğlu'}
# {'name': 'Easy 1 Bedroom in Chelsea'}
# ...

# %% [markdown]
# ### Assignment Q4: Update a few documents in the sample_airbnb DB

# %%
query = { "name": "Luxury Spacious Apartment" }
new_name = { "$set": { "name": "Luxury Villa" } }

listing_reviews.update_one(query, new_name)

# %% [markdown]
# ### Assignment Q5: Delete the documents that you added into the sample_airbnb DB

# %%
from bson.objectid import ObjectId
listing_reviews.delete_one({"name":"Luxury Villa"})

# %%
from bson.objectid import ObjectId
listing_reviews.delete_one({"name": "Luxury Spacious Apartment"})

# %%
delete_articles = listing_reviews.delete_many({ "name": { "$regex" : "BHK.*" }})
print(delete_articles.deleted_count, " listings deleted.")
# Out:
# 1  listings deleted.

# %%
for doc in listing_reviews.find({},{ "_id": 0, "name": 1, "propert_type": 1}):
    print(doc)
# Out:
# {'name': 'Ribeira Charming Duplex'}
# {'name': 'Horto flat with small garden'}
# {'name': 'Ocean View Waikiki Marina w/prkg'}
# {'name': 'Private Room in Bushwick'}
# {'name': 'Apt Linda Vista Lagoa - Rio'}
# {'name': 'New York City - Upper West Side Apt'}
# {'name': 'Copacabana Apartment Posto 6'}
# {'name': 'Charming Flat in Downtown Moda'}
# {'name': "Catete's Colonial Big Hause Room B"}
# {'name': 'Modern Spacious 1 Bedroom Loft'}
# {'name': 'Deluxe Loft Suite'}
# {'name': 'Ligne verte - à 15 min de métro du centre ville.'}
# {'name': 'Soho Cozy, Spacious and Convenient'}
# {'name': '3 chambres au coeur du Plateau'}
# {'name': 'Ótimo Apto proximo Parque Olimpico'}
# {'name': 'Double Room en-suite (307)'}
# {'name': 'Nice room in Barcelona Center'}
# {'name': 'Be Happy in Porto'}
# {'name': 'City center private room with bed'}
# {'name': 'Surry Hills Studio - Your Perfect Base in Sydney'}
# {'name': 'Cozy house at Beyoğlu'}
# {'name': 'Easy 1 Bedroom in Chelsea'}
# ...
